# %%
import jax
import jax.numpy as jnp
import jax.tree_util as jtu

import equinox as eqx
import optax
import einops
import matplotlib
import matplotlib.pyplot as plt
import ipdb
import tqdm.notebook as tqdm
import pprint

import infomec
import importlib
importlib.reload(infomec)
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()

# %%
INPUT_SIZE = 3
HIDDEN_SIZE = 256
SOURCE_SIZE = 3
LATENT_SIZE = 6
NUM_LAYERS = 6

def generate_data():
    s = jax.random.uniform(jax.random.PRNGKey(0), (10000, INPUT_SIZE), minval=0, maxval=1)
    
    # g = eqx.nn.MLP(SOURCE_SIZE, INPUT_SIZE, 64, 2, jnp.tanh, key=jax.random.PRNGKey(1))
    # x = jax.vmap(g)(s)
    # standardize x
    x = s
    x = (x - x.mean(0)) / x.std(0)
    return dict(x=x, s=s)
    
data = generate_data()
# Out:
# 2024-05-09 16:58:35.657673: W external/xla/xla/service/gpu/nvptx_compiler.cc:742] The NVIDIA driver's CUDA version is 12.2 which is older than the ptxas CUDA version (12.4.99). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.

# %%
fig, axes = plt.subplots(INPUT_SIZE, INPUT_SIZE, figsize=(20, 20))
for i in range(INPUT_SIZE):
    for j in range(INPUT_SIZE):
        axes[i, j].scatter(data['x'][:, i], data['x'][:, j])

# %%
class Model(eqx.Module):
    encoder: eqx.nn.MLP
    decoder: eqx.nn.MLP
    lambdas: dict
    num_params: int
    
    def __init__(self, *, key):
        keys = iter(jax.random.split(key, 100))
        self.encoder = eqx.nn.MLP(INPUT_SIZE, LATENT_SIZE, HIDDEN_SIZE, NUM_LAYERS, jax.nn.relu, key=next(keys))
        self.decoder = eqx.nn.MLP(LATENT_SIZE, INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, jax.nn.relu, key=next(keys))
        self.lambdas = {
            'reconstruction': 1.0,
            'activation_energy': 10,
            'activation_negativity': 10,
            'weight_energy': 1
        }
        self.num_params = sum(x.size for x in jtu.tree_leaves(eqx.filter(self, eqx.is_array)))
    
    def loss(self, model, data, *, key=None):
        x = data['x']
        z = jax.vmap(model.encoder)(x)
        x_hat = jax.vmap(model.decoder)(z)
        losses = {}
        losses['reconstruction'] = einops.reduce((x - x_hat) ** 2, 'n d -> n', 'mean')
        losses['activation_energy'] = einops.reduce(z ** 2, 'n d -> n', 'mean')
        losses['activation_negativity'] = einops.reduce((0.5 * (z - jnp.abs(z))) ** 2, 'n d -> n', 'mean')
        losses['weight_energy'] = Model.l2(model) / model.num_params
        losses['total'] = sum(losses[k] * model.lambdas[k] for k in losses.keys())
        aux = {
            'z': z,
            'x_hat': x_hat,
            'losses': losses
        }
        return jnp.mean(losses['total']), aux
        
    @staticmethod
    def l2(model):
        sum_squares = sum(jnp.sum(x ** 2) for x in jtu.tree_leaves(eqx.filter(model, eqx.is_array)))
        return jnp.sqrt(sum_squares)

@eqx.filter_jit
def train_step(model, optimizer_state, optimizer, data, *, key):
    (_, aux), grad = eqx.filter_value_and_grad(model.loss, has_aux=True)(model, data, key=key)
    update, optimizer_state = optimizer.update(grad, optimizer_state, model)
    model = eqx.apply_updates(model, update)
    return model, optimizer_state, aux

# %%
key = jax.random.PRNGKey(42)
model = Model(key=key)
optimizer = optax.adamw(learning_rate=1e-3, weight_decay=0)
optimizer_state = optimizer.init(eqx.filter(model, eqx.is_array))
print(model.num_params)
# Out:
# 663049

# %%
for _ in tqdm.trange(int(1e6)):
    key, subkey = jax.random.split(key)
    model, optimizer_state, aux = train_step(model, optimizer_state, optimizer, data, key=subkey)
    if _ % 2000 == 0:
        pprint.pprint(
            {k: jnp.mean(v).item() for k, v in aux['losses'].items()}
        )
        
        metrics = infomec.compute_infomec(data['s'], aux['z'], 'continuous', 'continuous')
        pprint.pprint(metrics)
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# {'activation_energy': 0.00023792505089659244,
#  'activation_negativity': 0.0001604894787305966,
#  'reconstruction': 1.0017215013504028,
#  'total': 1.0057553052902222,
#  'weight_energy': 4.955759868607856e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.1942411615345136,
#  'infoe': 0.6468778857304459,
#  'infom': 0.31495759801396,
#  'nmi': array([[0.0254674 , 0.0289018 , 0.11110996, 0.07598639, 0.03907994,
#         0.02656421],
#        [0.0295412 , 0.01989897, 0.01258776, 0.01162864, 0.06129732,
#         0.09292593],
#        [0.04102499, 0.03374374, 0.04380327, 0.03365131, 0.03013502,
#         0.02041047]])}
# {'activation_energy': 0.0005124020972289145,
#  'activation_negativity': 0.00012596489978022873,
#  'reconstruction': 0.025386273860931396,
#  'total': 0.03181978687644005,
#  'weight_energy': 4.9843925808090717e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.14186293076312026,
#  'infoe': 0.5330832899313466,
#  'infom': 0.314058540931255,
#  'nmi': array([[0.11040687, 0.0633284 , 0.02942452, 0.09289013, 0.03009503,
#         0.09115323],
#        [0.04908961, 0.04655451, 0.03378096, 0.01972093, 0.03430189,
#         0.02734371],
#        [0.03315126, 0.03377557, 0.08061496, 0.03792529, 0.02406632,
#         0.01615258]])}
# {'activation_energy': 0.0001302489690715447,
#  'activation_negativity': 3.70966772607062e-05,
#  'reconstruction': 0.002314730314537883,
#  'total': 0.004038498271256685,
#  'weight_energy': 5.0310951337451115e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.16586434875821754,
#  'infoe': 0.5338279843354434,
#  'infom': 0.3703944849366216,
#  'nmi': array([[0.09140406, 0.07535456, 0.01944663, 0.03444415, 0.01917731,
#         0.0822904 ],
#        [0.04436023, 0.0932988 , 0.02073011, 0.01730016, 0.07487621,
#         0.05594618],
#        [0.01452455, 0.01785546, 0.07598453, 0.07825299, 0.02819832,
#         0.02484797]])}
# {'activation_energy': 0.00010884854418691248,
#  'activation_negativity': 2.883955676225014e-05,
#  'reconstruction': 0.002258456312119961,
#  'total': 0.003685395000502467,
#  'weight_energy': 5.005771163268946e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.1924337636891694,
#  'infoe': 0.5718232291868469,
#  'infom': 0.37380392535145673,
#  'nmi': array([[0.10964243, 0.09843265, 0.02074309, 0.02958542, 0.02349625,
#         0.09173186],
#        [0.06460968, 0.09213136, 0.02547464, 0.01400848, 0.10005079,
#         0.05677363],
#        [0.01218612, 0.01430034, 0.05652628, 0.08991793, 0.02551238,
#         0.02399236]])}
# {'activation_energy': 0.00013507928815670311,
#  'activation_negativity': 4.333959077484906e-05,
#  'reconstruction': 0.009997239336371422,
#  'total': 0.01183572132140398,
#  'weight_energy': 5.429330485640094e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.26075115138549554,
#  'infoe': 0.4927249744209597,
#  'infom': 0.4567802160188517,
#  'nmi': array([[0.0892797 , 0.11320296, 0.02515847, 0.00735535, 0.03968906,
#         0.03074247],
#        [0.03971931, 0.03329063, 0.09820349, 0.00791448, 0.07218723,
#         0.04910308],
#        [0.04801292, 0.04693446, 0.02953195, 0.18716698, 0.00387819,
#         0.09641865]])}
# {'activation_energy': 8.040505781536922e-05,
#  'activation_negativity': 2.859204869309906e-05,
#  'reconstruction': 0.0005280727637000382,
#  'total': 0.0016741204308345914,
#  'weight_energy': 5.607662387774326e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.25632287990937236,
#  'infoe': 0.8041822255614162,
#  'infom': 0.3599598728972693,
#  'nmi': array([[0.07182329, 0.06620598, 0.04051042, 0.02123087, 0.0643539 ,
#         0.08098057],
#        [0.02014738, 0.06670366, 0.04086446, 0.00341644, 0.10543597,
#         0.04182343],
#        [0.0273027 , 0.01099769, 0.05646427, 0.1555274 , 0.00685295,
#         0.03773873]])}
# {'activation_energy': 5.9520945796975866e-05,
#  'activation_negativity': 1.3507198673323728e-05,
#  'reconstruction': 0.003585128579288721,
#  'total': 0.004371117800474167,
#  'weight_energy': 5.570757275563665e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.2935867877438357,
#  'infoe': 0.8633939570693635,
#  'infom': 0.41800923821191094,
#  'nmi': array([[0.07956706, 0.07118929, 0.03880889, 0.02281738, 0.04758139,
#         0.08804215],
#        [0.02597793, 0.07122382, 0.03558261, 0.00231243, 0.1288747 ,
#         0.03432385],
#        [0.01838073, 0.00849669, 0.05727861, 0.15354598, 0.00309317,
#         0.03891866]])}
# {'activation_energy': 5.5552252888446674e-05,
#  'activation_negativity': 1.354669439024292e-05,
#  'reconstruction': 0.0011372982989996672,
#  'total': 0.001883633784018457,
#  'weight_energy': 5.534606316359714e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.30681479183118143,
#  'infoe': 0.9119592659035097,
#  'infom': 0.4536359579912108,
#  'nmi': array([[0.07099998, 0.07300149, 0.04748891, 0.03328941, 0.02834779,
#         0.11843942],
#        [0.04690089, 0.09115804, 0.02200069, 0.00199019, 0.13783201,
#         0.01872977],
#        [0.01802992, 0.00792645, 0.05598086, 0.11602777, 0.0027429 ,
#         0.02429235]])}
# {'activation_energy': 4.9855159886647016e-05,
#  'activation_negativity': 1.23276658996474e-05,
#  'reconstruction': 0.0007484779343940318,
#  'total': 0.0014256194699555635,
#  'weight_energy': 5.531318311113864e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.34707922870300734,
#  'infoe': 0.937386121213855,
#  'infom': 0.47710816417194996,
#  'nmi': array([[0.06915165, 0.08066729, 0.03733212, 0.02654469, 0.01825985,
#         0.10198011],
#        [0.03251902, 0.07471919, 0.02617807, 0.00302848, 0.16199078,
#         0.0164282 ],
#        [0.01727377, 0.00526119, 0.0503889 , 0.12892954, 0.00217652,
#         0.0313157 ]])}
# {'activation_energy': 5.211095776758157e-05,
#  'activation_negativity': 1.4415265468414873e-05,
#  'reconstruction': 0.0010933587327599525,
#  'total': 0.001813127426430583,
#  'weight_energy': 5.4506621381733567e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.3690334126826758,
#  'infoe': 0.9518602425707963,
#  'infom': 0.5212207795286332,
#  'nmi': array([[0.05931498, 0.08208043, 0.03298405, 0.01510427, 0.01263682,
#         0.09018434],
#        [0.02748466, 0.06749778, 0.01791434, 0.00172889, 0.16689043,
#         0.00742761],
#        [0.02391801, 0.0071263 , 0.06338671, 0.16002886, 0.00241583,
#         0.04142561]])}
# {'activation_energy': 4.421704579726793e-05,
#  'activation_negativity': 1.1096190064563416e-05,
#  'reconstruction': 0.0001358151639578864,
#  'total': 0.0007429184624925256,
#  'weight_energy': 5.397093991632573e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.3764617386249753,
#  'infoe': 0.9619026955464451,
#  'infom': 0.49040561449928466,
#  'nmi': array([[0.05679741, 0.07690895, 0.04188418, 0.02096623, 0.0112534 ,
#         0.09546149],
#        [0.03216838, 0.0639126 , 0.01699829, 0.00062354, 0.17256723,
#         0.00784849],
#        [0.02078587, 0.00743166, 0.04979024, 0.1389196 , 0.00523298,
#         0.0352625 ]])}
# {'activation_energy': 3.71751120837871e-05,
#  'activation_negativity': 9.023502570926212e-06,
#  'reconstruction': 5.476590740727261e-05,
#  'total': 0.0005704417708329856,
#  'weight_energy': 5.3689673222834244e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.39678516497815486,
#  'infoe': 0.9750707820493846,
#  'infom': 0.49209297263405166,
#  'nmi': array([[0.05336   , 0.07451218, 0.04643914, 0.02599587, 0.00706388,
#         0.10077978],
#        [0.03775357, 0.05796121, 0.01647573, 0.00113417, 0.19158302,
#         0.00572275],
#        [0.01819214, 0.0049624 , 0.04388224, 0.12208189, 0.00273219,
#         0.03086106]])}
# {'activation_energy': 3.5772733099292964e-05,
#  'activation_negativity': 9.06611603568308e-06,
#  'reconstruction': 0.00012849981430917978,
#  'total': 0.0006305116694420576,
#  'weight_energy': 5.362336742109619e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.40302392119069597,
#  'infoe': 0.9817919319731948,
#  'infom': 0.47488862705016616,
#  'nmi': array([[0.045631  , 0.07183303, 0.0435383 , 0.02252118, 0.0053298 ,
#         0.08641703],
#        [0.0375351 , 0.05371272, 0.01863817, 0.00104813, 0.20313909,
#         0.00766357],
#        [0.02009399, 0.004423  , 0.03947017, 0.13170579, 0.00471476,
#         0.03384344]])}
# {'activation_energy': 3.737074803211726e-05,
#  'activation_negativity': 1.0178053344134241e-05,
#  'reconstruction': 7.747752533759922e-05,
#  'total': 0.0006069372757337987,
#  'weight_energy': 5.397173299570568e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.4028911782935413,
#  'infoe': 0.9849100605600364,
#  'infom': 0.4889687393233997,
#  'nmi': array([[0.04846474, 0.07041316, 0.05078325, 0.0264703 , 0.00272182,
#         0.0864398 ],
#        [0.04060764, 0.05319926, 0.01978431, 0.00114143, 0.21821471,
#         0.00938511],
#        [0.01730758, 0.00498997, 0.03152483, 0.11841543, 0.00561784,
#         0.03106104]])}
# {'activation_energy': 3.3896256354637444e-05,
#  'activation_negativity': 8.711717782716732e-06,
#  'reconstruction': 0.00020940710965078324,
#  'total': 0.0006899004802107811,
#  'weight_energy': 5.4413641919381917e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.4165643278887123,
#  'infoe': 0.9868887923277555,
#  'infom': 0.5066842248405716,
#  'nmi': array([[0.04993875, 0.07946574, 0.0456287 , 0.02804047, 0.00235788,
#         0.09049159],
#        [0.03600679, 0.04489225, 0.02195443, 0.00082161, 0.22890217,
#         0.00774964],
#        [0.01876892, 0.00435886, 0.03022147, 0.11601592, 0.00488834,
#         0.03180595]])}
# {'activation_energy': 2.6455836632521823e-05,
#  'activation_negativity': 6.337760169117246e-06,
#  'reconstruction': 6.821278657298535e-05,
#  'total': 0.0004511876904871315,
#  'weight_energy': 5.503895226866007e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.41923792815939975,
#  'infoe': 0.9908503558147587,
#  'infom': 0.5177412696634116,
#  'nmi': array([[0.05546904, 0.08461528, 0.0444936 , 0.02578164, 0.00175133,
#         0.08273856],
#        [0.02826311, 0.03953215, 0.02065384, 0.00057672, 0.23507506,
#         0.00756985],
#        [0.02229488, 0.00450285, 0.03401844, 0.13005141, 0.00591731,
#         0.03866339]])}
# {'activation_energy': 3.158107938361354e-05,
#  'activation_negativity': 7.840509169909637e-06,
#  'reconstruction': 0.00044112937757745385,
#  'total': 0.0008910031756386161,
#  'weight_energy': 5.565783067140728e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.4422720448786665,
#  'infoe': 0.9883917041616056,
#  'infom': 0.520271218673735,
#  'nmi': array([[0.05170519, 0.09152642, 0.03920538, 0.01885657, 0.00057633,
#         0.08170815],
#        [0.02808235, 0.03591956, 0.02078742, 0.00069151, 0.23784395,
#         0.00665735],
#        [0.02403098, 0.00425492, 0.03639637, 0.14472433, 0.00680998,
#         0.04123307]])}
# {'activation_energy': 3.09267888951581e-05,
#  'activation_negativity': 8.628446266811807e-06,
#  'reconstruction': 5.998853157507256e-05,
#  'total': 0.000511944352183491,
#  'weight_energy': 5.6403438065899536e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.4905139602908844,
#  'infoe': 0.9896097290167859,
#  'infom': 0.5583495664589554,
#  'nmi': array([[0.05184906, 0.10876526, 0.03490359, 0.01305957, 0.00147757,
#         0.08018918],
#        [0.01987131, 0.02456142, 0.01888923, 0.00189527, 0.26369394,
#         0.00605297],
#        [0.03118736, 0.00444144, 0.04381527, 0.1723493 , 0.0054866 ,
#         0.04813195]])}
# {'activation_energy': 2.5488890969427302e-05,
#  'activation_negativity': 6.253588253457565e-06,
#  'reconstruction': 2.8255411962163635e-05,
#  'total': 0.00040270050521939993,
#  'weight_energy': 5.702031194232404e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.4572727861237396,
#  'infoe': 0.9916469540167467,
#  'infom': 0.5486519452984291,
#  'nmi': array([[0.05644355, 0.10149175, 0.04083465, 0.02120574, 0.00071349,
#         0.08400364],
#        [0.02632387, 0.02974772, 0.02145539, 0.00068851, 0.24480378,
#         0.00744508],
#        [0.02261113, 0.00296949, 0.03304893, 0.13910142, 0.00701095,
#         0.03959599]])}
# {'activation_energy': 2.5554138119332492e-05,
#  'activation_negativity': 6.303465852397494e-06,
#  'reconstruction': 0.0003504424821585417,
#  'total': 0.0007267356850206852,
#  'weight_energy': 5.7717148592928424e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.45526297171790436,
#  'infoe': 0.99148110000024,
#  'infom': 0.5520032443931882,
#  'nmi': array([[0.05802921, 0.10031452, 0.03995283, 0.02348897, 0.00147842,
#         0.08922094],
#        [0.02790858, 0.03159662, 0.02414968, 0.00047139, 0.25725789,
#         0.00794108],
#        [0.01849926, 0.00212555, 0.03043637, 0.13015326, 0.00573087,
#         0.03718902]])}
# {'activation_energy': 2.2967380573390983e-05,
#  'activation_negativity': 5.603644694929244e-06,
#  'reconstruction': 9.798650717129931e-05,
#  'total': 0.0004420457116793841,
#  'weight_energy': 5.834897456225008e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.4678013394951797,
#  'infoe': 0.991960442144474,
#  'infom': 0.5587887654967274,
#  'nmi': array([[0.0576207 , 0.10740654, 0.04037648, 0.02127857, 0.00097662,
#         0.08614298],
#        [0.02577505, 0.02871365, 0.02238338, 0.00101153, 0.25230451,
#         0.00723494],
#        [0.02136292, 0.00329166, 0.03136874, 0.13920729, 0.00592086,
#         0.03907275]])}
# {'activation_energy': 2.6298068405594677e-05,
#  'activation_negativity': 6.850230420241132e-06,
#  'reconstruction': 0.00029815378366038203,
#  'total': 0.0006886593764647841,
#  'weight_energy': 5.902250268263742e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.47444888428691145,
#  'infoe': 0.9910722025779174,
#  'infom': 0.6262627512357075,
#  'nmi': array([[0.06959768, 0.12902367, 0.05242594, 0.03018766, 0.00050593,
#         0.10673396],
#        [0.02180003, 0.02501892, 0.01992244, 0.        , 0.2512783 ,
#         0.00600459],
#        [0.01867211, 0.0023213 , 0.02695505, 0.11290332, 0.00546376,
#         0.02884969]])}
# {'activation_energy': 2.5975203243433498e-05,
#  'activation_negativity': 6.928794846317032e-06,
#  'reconstruction': 0.0020162395667284727,
#  'total': 0.0024049768690019846,
#  'weight_energy': 5.969738413114101e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.48619086955885604,
#  'infoe': 0.9918244250742053,
#  'infom': 0.6588237527770803,
#  'nmi': array([[0.07506701, 0.13891843, 0.05868769, 0.03263946, 0.00045788,
#         0.11526217],
#        [0.01924777, 0.02253043, 0.01796471, 0.        , 0.251552  ,
#         0.00562793],
#        [0.01730408, 0.00265693, 0.02483397, 0.10865956, 0.0055985 ,
#         0.02455629]])}
# {'activation_energy': 2.5796147383516654e-05,
#  'activation_negativity': 6.741799097653711e-06,
#  'reconstruction': 8.379058272112161e-05,
#  'total': 0.0004695160605479032,
#  'weight_energy': 6.034597026882693e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.4815481769421275,
#  'infoe': 0.9909850193306967,
#  'infom': 0.5821054696205366,
#  'nmi': array([[5.78250176e-02, 1.19740222e-01, 4.22384382e-02, 2.34180213e-02,
#         1.88044562e-03, 9.04710045e-02],
#        [2.47436101e-02, 2.68934788e-02, 2.38179103e-02, 1.03137392e-04,
#         2.52162458e-01, 7.08470566e-03],
#        [1.98569241e-02, 1.94675332e-03, 2.74326368e-02, 1.29797354e-01,
#         5.79040836e-03, 3.37319536e-02]])}
# {'activation_energy': 2.2428952433983795e-05,
#  'activation_negativity': 5.7292936617159285e-06,
#  'reconstruction': 0.00018390505283605307,
#  'total': 0.0005263751372694969,
#  'weight_energy': 6.0887643485330045e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.49683297639223395,
#  'infoe': 0.9911246652351267,
#  'infom': 0.5528860643270548,
#  'nmi': array([[0.05567514, 0.11920678, 0.03389376, 0.01883353, 0.00173361,
#         0.08007411],
#        [0.02459709, 0.02578988, 0.02583359, 0.00107877, 0.27384891,
#         0.00658774],
#        [0.02241063, 0.00213279, 0.03223205, 0.14608948, 0.00385553,
#         0.0403385 ]])}
# {'activation_energy': 2.108500848407857e-05,
#  'activation_negativity': 5.2229252105462365e-06,
#  'reconstruction': 2.2079293557908386e-05,
#  'total': 0.0003466222551651299,
#  'weight_energy': 6.146363011794165e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.49883243273148814,
#  'infoe': 0.9927584251877927,
#  'infom': 0.6187771850907063,
#  'nmi': array([[6.43340903e-02, 1.40397057e-01, 4.78339970e-02, 2.53168795e-02,
#         1.49751414e-03, 9.37779902e-02],
#        [2.10772898e-02, 1.95558106e-02, 2.28188612e-02, 1.40792600e-04,
#         2.47885411e-01, 7.58104727e-03],
#        [2.07558906e-02, 2.73578661e-03, 2.56495925e-02, 1.26350470e-01,
#         5.55722027e-03, 3.16929549e-02]])}
# {'activation_energy': 2.1384474166552536e-05,
#  'activation_negativity': 5.24060988027486e-06,
#  'reconstruction': 0.00021156530419830233,
#  'total': 0.0005398120847530663,
#  'weight_energy': 6.199593190103769e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.49643313384243687,
#  'infoe': 0.9918599222914409,
#  'infom': 0.5997777419386938,
#  'nmi': array([[0.06360097, 0.1360466 , 0.04354277, 0.02284195, 0.00212769,
#         0.08778147],
#        [0.02153766, 0.02222274, 0.02267459, 0.00073583, 0.24958633,
#         0.00570698],
#        [0.02015022, 0.00295407, 0.02861227, 0.13238243, 0.00465252,
#         0.03759375]])}
# {'activation_energy': 2.1037783881183714e-05,
#  'activation_negativity': 5.207776212046156e-06,
#  'reconstruction': 9.74112335825339e-05,
#  'total': 0.0004223905852995813,
#  'weight_energy': 6.252378079807386e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.4961339280256585,
#  'infoe': 0.9916240112499284,
#  'infom': 0.586153671523023,
#  'nmi': array([[0.06160151, 0.13196998, 0.04008717, 0.02097391, 0.00235267,
#         0.08501897],
#        [0.02301857, 0.0225295 , 0.02449249, 0.00059282, 0.24953945,
#         0.00622075],
#        [0.01993372, 0.00273565, 0.02932196, 0.13773332, 0.00431837,
#         0.03943217]])}
# {'activation_energy': 2.026780384767335e-05,
#  'activation_negativity': 5.11462440044852e-06,
#  'reconstruction': 3.5203385778004304e-05,
#  'total': 0.00035205946187488735,
#  'weight_energy': 6.30318172625266e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.4945874925929373,
#  'infoe': 0.9921613816055066,
#  'infom': 0.5995422369230097,
#  'nmi': array([[0.06320976, 0.13136235, 0.04376903, 0.0240676 , 0.00320083,
#         0.09057688],
#        [0.02460903, 0.02313105, 0.02713955, 0.00053274, 0.25509539,
#         0.00655792],
#        [0.01663618, 0.00252327, 0.02473291, 0.12979794, 0.00332359,
#         0.03547199]])}
# {'activation_energy': 2.000014683289919e-05,
#  'activation_negativity': 4.942687610309804e-06,
#  'reconstruction': 0.0009657888440415263,
#  'total': 0.0012787323212251067,
#  'weight_energy': 6.351506453938782e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.5089097614531964,
#  'infoe': 0.9924730193029023,
#  'infom': 0.623155273075215,
#  'nmi': array([[0.0661089 , 0.15134117, 0.04747627, 0.02286414, 0.000959  ,
#         0.08885976],
#        [0.02064764, 0.01814473, 0.02285923, 0.00086178, 0.24275343,
#         0.00566959],
#        [0.01918307, 0.00265744, 0.02643715, 0.13011454, 0.00554682,
#         0.0363069 ]])}
# {'activation_energy': 1.9621771571110003e-05,
#  'activation_negativity': 4.903502940578619e-06,
#  'reconstruction': 0.00012718900688923895,
#  'total': 0.00043643845128826797,
#  'weight_energy': 6.399673293344676e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.5063512550926096,
#  'infoe': 0.9917507050766305,
#  'infom': 0.5767630757292217,
#  'nmi': array([[0.06243154, 0.14885121, 0.03816904, 0.02024176, 0.00143492,
#         0.07566   ],
#        [0.02210843, 0.01977397, 0.02463903, 0.0006603 , 0.24224382,
#         0.00469123],
#        [0.02073435, 0.00328655, 0.02954952, 0.13785961, 0.00504887,
#         0.04732185]])}
# {'activation_energy': 1.8909506252384745e-05,
#  'activation_negativity': 4.843834631174104e-06,
#  'reconstruction': 0.00030740397050976753,
#  'total': 0.0006094119744375348,
#  'weight_energy': 6.447457417380065e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.5026850746560055,
#  'infoe': 0.9924269688195392,
#  'infom': 0.5773063105612979,
#  'nmi': array([[0.05957046, 0.13499885, 0.03870442, 0.02208854, 0.00319299,
#         0.08288822],
#        [0.0267509 , 0.02377756, 0.0305103 , 0.00039416, 0.26221077,
#         0.00661497],
#        [0.01724084, 0.00074283, 0.02443296, 0.13562685, 0.00389011,
#         0.03942013]])}
# {'activation_energy': 1.865920057753101e-05,
#  'activation_negativity': 4.623107543011429e-06,
#  'reconstruction': 0.00026666949270293117,
#  'total': 0.0005643680924549699,
#  'weight_energy': 6.487551581813022e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.5083657707965948,
#  'infoe': 0.9924355340202474,
#  'infom': 0.6100961701294797,
#  'nmi': array([[0.06587527, 0.15033018, 0.04511871, 0.02244295, 0.00240542,
#         0.08460737],
#        [0.02305781, 0.01878804, 0.02447906, 0.00102597, 0.24480351,
#         0.00556192],
#        [0.01719238, 0.00171515, 0.02558155, 0.13295281, 0.0051117 ,
#         0.04091096]])}
# {'activation_energy': 2.1285040929797105e-05,
#  'activation_negativity': 5.583510301221395e-06,
#  'reconstruction': 0.0006456205737777054,
#  'total': 0.0009795918595045805,
#  'weight_energy': 6.52858434477821e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.5180513794125574,
#  'infoe': 0.9913393159472005,
#  'infom': 0.6470509003390863,
#  'nmi': array([[0.06962695, 0.15225776, 0.05053247, 0.01910708, 0.00380491,
#         0.09489697],
#        [0.02064456, 0.01675466, 0.01899939, 0.00058356, 0.23195285,
#         0.00519046],
#        [0.01778435, 0.00410841, 0.02687728, 0.14483499, 0.00598702,
#         0.03540325]])}
# {'activation_energy': 1.786844222806394e-05,
#  'activation_negativity': 4.441323653736617e-06,
#  'reconstruction': 5.778787090093829e-05,
#  'total': 0.0003465566551312804,
#  'weight_energy': 6.567111267941073e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.4996053297487727,
#  'infoe': 0.9926391066574293,
#  'infom': 0.6033119261858457,
#  'nmi': array([[0.06570567, 0.15464487, 0.04627381, 0.02265743, 0.00248202,
#         0.08275776],
#        [0.02289279, 0.01714297, 0.02307371, 0.00086938, 0.22662368,
#         0.00581871],
#        [0.01800383, 0.00264288, 0.02675277, 0.13246952, 0.00653534,
#         0.0453609 ]])}
# {'activation_energy': 2.1204661607043818e-05,
#  'activation_negativity': 5.477570539369481e-06,
#  'reconstruction': 7.925664976937696e-05,
#  'total': 0.0004121230449527502,
#  'weight_energy': 6.604407099075615e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.49961334040647243,
#  'infoe': 0.991301896879603,
#  'infom': 0.6352391589495296,
#  'nmi': array([[0.07179174, 0.15669085, 0.05317704, 0.02521922, 0.00276415,
#         0.08850108],
#        [0.02326175, 0.01520409, 0.01962308, 0.00124432, 0.21465729,
#         0.00536237],
#        [0.01580211, 0.00321149, 0.02481622, 0.12641001, 0.0065426 ,
#         0.0385407 ]])}
# {'activation_energy': 1.7568718249094673e-05,
#  'activation_negativity': 4.257637556293048e-06,
#  'reconstruction': 0.0007756645209155977,
#  'total': 0.0010602910770103335,
#  'weight_energy': 6.636307807639241e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.5071538222065172,
#  'infoe': 0.9926625978811997,
#  'infom': 0.6483160773009398,
#  'nmi': array([[0.07677755, 0.16694793, 0.05392791, 0.02897889, 0.00278994,
#         0.09413512],
#        [0.02257166, 0.01474448, 0.02082482, 0.00049269, 0.23474943,
#         0.00465966],
#        [0.01422905, 0.00273243, 0.0231275 , 0.1154103 , 0.005347  ,
#         0.036069  ]])}
# {'activation_energy': 1.8305587218492292e-05,
#  'activation_negativity': 4.505824108491652e-06,
#  'reconstruction': 0.0013061267090961337,
#  'total': 0.0016009685350582004,
#  'weight_energy': 6.672759627690539e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.5044312436120003,
#  'infoe': 0.9923521184233269,
#  'infom': 0.6440575501936572,
#  'nmi': array([[0.07837155, 0.16105311, 0.0522965 , 0.02720406, 0.00411758,
#         0.09266419],
#        [0.02173835, 0.01597168, 0.02039216, 0.00096473, 0.23347564,
#         0.00425741],
#        [0.01389071, 0.00238102, 0.02503288, 0.12097365, 0.00464411,
#         0.03916028]])}
# {'activation_energy': 1.9834349586744793e-05,
#  'activation_negativity': 5.045324996899581e-06,
#  'reconstruction': 4.8255609726766124e-05,
#  'total': 0.0003640974755398929,
#  'weight_energy': 6.704508268740028e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.5210760071986021,
#  'infoe': 0.990788439938635,
#  'infom': 0.6056736169444092,
#  'nmi': array([[0.07312483, 0.15579969, 0.03970223, 0.01806519, 0.00304507,
#         0.07712242],
#        [0.01910505, 0.01585737, 0.02136893, 0.00044056, 0.24997295,
#         0.0043355 ],
#        [0.01823063, 0.00285017, 0.03298165, 0.14618596, 0.0038863 ,
#         0.05034909]])}
# {'activation_energy': 1.7274456695304252e-05,
#  'activation_negativity': 4.359300874057226e-06,
#  'reconstruction': 4.075782999279909e-05,
#  'total': 0.00032444208045490086,
#  'weight_energy': 6.734670023433864e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.4974248679923097,
#  'infoe': 0.9924977457984087,
#  'infom': 0.6207732300781976,
#  'nmi': array([[0.07667555, 0.15775772, 0.04847874, 0.02911999, 0.00194675,
#         0.08518287],
#        [0.02486595, 0.0175426 , 0.02479478, 0.00051956, 0.24319836,
#         0.00506553],
#        [0.01267692, 0.00192476, 0.02169605, 0.11430109, 0.00533402,
#         0.04158334]])}
# {'activation_energy': 1.7708056475385092e-05,
#  'activation_negativity': 4.426871782925446e-06,
#  'reconstruction': 2.6592832000460476e-05,
#  'total': 0.0003155542362947017,
#  'weight_energy': 6.76120980642736e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.5038895288965641,
#  'infoe': 0.9923222958360881,
#  'infom': 0.6528728516657054,
#  'nmi': array([[0.08093018, 0.16230668, 0.05456114, 0.02681439, 0.00245652,
#         0.09098502],
#        [0.02129368, 0.01502952, 0.01983927, 0.0006412 , 0.22629676,
#         0.00570684],
#        [0.01361206, 0.00204892, 0.02317663, 0.11919908, 0.00616487,
#         0.03854413]])}
# {'activation_energy': 1.60825493367156e-05,
#  'activation_negativity': 4.170942247583298e-06,
#  'reconstruction': 1.5339963283622637e-05,
#  'total': 0.0002857609069906175,
#  'weight_energy': 6.788602331653237e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.4989408992526934,
#  'infoe': 0.9926307611700084,
#  'infom': 0.6091832470618868,
#  'nmi': array([[0.07162831, 0.14728731, 0.04601096, 0.02625767, 0.00279773,
#         0.08285539],
#        [0.02595172, 0.01801839, 0.02604929, 0.00059533, 0.24474629,
#         0.00616151],
#        [0.01336712, 0.00167466, 0.02230963, 0.12459263, 0.00388212,
#         0.04347095]])}
# {'activation_energy': 1.6357415006496012e-05,
#  'activation_negativity': 4.087332399649313e-06,
#  'reconstruction': 0.00024615443544462323,
#  'total': 0.0005187185015529394,
#  'weight_energy': 6.81166275171563e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.496069195456539,
#  'infoe': 0.99247145257794,
#  'infom': 0.6338216718631555,
#  'nmi': array([[0.07809605, 0.15964945, 0.05282898, 0.02747147, 0.00273865,
#         0.08640239],
#        [0.02260377, 0.01669824, 0.02094603, 0.00068666, 0.22648609,
#         0.00712295],
#        [0.01276375, 0.00141505, 0.02349604, 0.1186471 , 0.00550966,
#         0.04303073]])}
# {'activation_energy': 1.9946786778746173e-05,
#  'activation_negativity': 5.30395891473745e-06,
#  'reconstruction': 2.6588015316519886e-05,
#  'total': 0.0003475425182841718,
#  'weight_energy': 6.844705058028921e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.48880407038291923,
#  'infoe': 0.9914094914416437,
#  'infom': 0.5961573042585642,
#  'nmi': array([[0.07099101, 0.15836323, 0.05157562, 0.02222348, 0.002083  ,
#         0.06571345],
#        [0.02131458, 0.01651366, 0.01847005, 0.00071194, 0.18518221,
#         0.00648179],
#        [0.01822901, 0.00333001, 0.02715136, 0.13551484, 0.01022386,
#         0.05175381]])}
# {'activation_energy': 1.660388988966588e-05,
#  'activation_negativity': 4.1469406824035104e-06,
#  'reconstruction': 1.55741236085305e-05,
#  'total': 0.00029169657500460744,
#  'weight_energy': 6.861412839498371e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.5029297356416124,
#  'infoe': 0.992122411042736,
#  'infom': 0.5985209126189143,
#  'nmi': array([[0.07288133, 0.15898691, 0.04769452, 0.02036073, 0.00204596,
#         0.06720047],
#        [0.02070949, 0.0165223 , 0.0200238 , 0.00073639, 0.21217048,
#         0.00639648],
#        [0.01730441, 0.00257624, 0.02936182, 0.14088067, 0.00661882,
#         0.05506277]])}
# {'activation_energy': 1.6168231013580225e-05,
#  'activation_negativity': 4.13072484661825e-06,
#  'reconstruction': 1.4184641258907504e-05,
#  'total': 0.00028595805633813143,
#  'weight_energy': 6.878384738229215e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.5000703715693336,
#  'infoe': 0.9924008202999417,
#  'infom': 0.6425167626288488,
#  'nmi': array([[0.08077911, 0.16328145, 0.05568758, 0.02889285, 0.00348804,
#         0.08654266],
#        [0.02249581, 0.01595187, 0.02148845, 0.00029831, 0.23170598,
#         0.00867044],
#        [0.01198571, 0.00175182, 0.02154652, 0.11495922, 0.00476353,
#         0.04003989]])}
# {'activation_energy': 1.8104276023223065e-05,
#  'activation_negativity': 4.741637440019986e-06,
#  'reconstruction': 0.00013795327686239034,
#  'total': 0.0004353787226136774,
#  'weight_energy': 6.896629929542542e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.49227450892404084,
#  'infoe': 0.991516266095064,
#  'infom': 0.6488464806448648,
#  'nmi': array([[0.09118724, 0.17401999, 0.05941622, 0.02986644, 0.00435218,
#         0.08101337],
#        [0.01870029, 0.01372075, 0.01826582, 0.        , 0.2127503 ,
#         0.00852801],
#        [0.01117747, 0.00230002, 0.02312385, 0.10948678, 0.0058386 ,
#         0.0461369 ]])}
# {'activation_energy': 1.587377664691303e-05,
#  'activation_negativity': 3.706004463310819e-06,
#  'reconstruction': 0.003090298268944025,
#  'total': 0.0033552164677530527,
#  'weight_energy': 6.912031676620245e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.5015923311144408,
#  'infoe': 0.9923229910744148,
#  'infom': 0.6291522177310831,
#  'nmi': array([[0.0793138 , 0.16518732, 0.05500397, 0.02513513, 0.00338128,
#         0.07201625],
#        [0.02009666, 0.01477937, 0.0185565 , 0.00038996, 0.21132194,
#         0.00919619],
#        [0.01321101, 0.00191833, 0.02482559, 0.12497514, 0.00610251,
#         0.04792969]])}
# {'activation_energy': 1.4622637536376715e-05,
#  'activation_negativity': 3.6171279589325422e-06,
#  'reconstruction': 8.541656279703602e-05,
#  'total': 0.00033709482522681355,
#  'weight_energy': 6.928063521627337e-05}
# pruned_nmi shape: (3, 6)
# {'active_latents': array([ True,  True,  True,  True,  True,  True]),
#  'infoc': 0.5030206295820155,
#  'infoe': 0.9927376211989034,
#  'infom': 0.6104862835161702,
#  'nmi': array([[0.07621324, 0.15845765, 0.05361636, 0.02714317, 0.00347975,
#         0.06349373],
#        [0.02352592, 0.0170811 , 0.02137552, 0.00026505, 0.22569257,
#         0.01205586],
#        [0.01299065, 0.00223412, 0.02214747, 0.12063775, 0.00481308,
#         0.0413499 ]])}
# {'activation_energy': 1.6913891158765182e-05,
#  'activation_negativity': 4.144748345424887e-06,
#  'reconstruction': 0.0003294860362075269,
#  'total': 0.0006095420685596764,
#  'weight_energy': 6.94696354912594e-05}
# pruned_nmi shape: (3, 5)
# {'active_latents': array([ True,  True,  True,  True,  True, False]),
#  'infoc': 0.590009947435479,
#  'infoe': 0.991279183165572,
#  'infom': 0.6851324986343331,
#  'nmi': array([[0.08163893, 0.16450256, 0.05389036, 0.02565236, 0.00292889,
#         0.03677547],
#        [0.0198621 , 0.01517794, 0.01866687, 0.0005413 , 0.20613502,
#         0.01370572],
#        [0.01248684, 0.00160124, 0.02560864, 0.12213354, 0.00691673,
#         0.039565  ]])}
# {'activation_energy': 2.107600448653102e-05,
#  'activation_negativity': 5.7186393860320095e-06,
#  'reconstruction': 0.0002954930532723665,
#  'total': 0.0006330847390927374,
#  'weight_energy': 6.964521890040487e-05}
# pruned_nmi shape: (3, 5)
# {'active_latents': array([ True,  True,  True,  True,  True, False]),
#  'infoc': 0.5732705631644649,
#  'infoe': 0.9900209943531927,
#  'infom': 0.7114176896651182,
#  'nmi': array([[0.10950192, 0.1821884 , 0.07669156, 0.04223903, 0.00922443,
#         0.01743317],
#        [0.01839714, 0.01440586, 0.01524009, 0.        , 0.18995407,
#         0.01160798],
#        [0.00612475, 0.00126508, 0.01801874, 0.08421813, 0.00360445,
#         0.01386276]])}
# {'activation_energy': 1.4586988982046023e-05,
#  'activation_negativity': 3.6665937841462437e-06,
#  'reconstruction': 0.00016764187603257596,
#  'total': 0.0004199474351480603,
#  'weight_energy': 6.976974691497162e-05}
# pruned_nmi shape: (3, 5)
# {'active_latents': array([ True,  True,  True,  True,  True, False]),
#  'infoc': 0.5919727251464494,
#  'infoe': 0.9922610989123338,
#  'infom': 0.6767525275832936,
#  'nmi': array([[7.80178034e-02, 1.61582609e-01, 5.29533854e-02, 2.52528355e-02,
#         3.91235023e-03, 1.21216365e-02],
#        [2.12338783e-02, 1.63004913e-02, 1.93843974e-02, 1.72156051e-04,
#         2.13190171e-01, 1.09245549e-02],
#        [1.28569684e-02, 2.47224108e-03, 2.52121322e-02, 1.24428976e-01,
#         5.54694578e-03, 2.03746176e-02]])}
# {'activation_energy': 1.4048320736037567e-05,
#  'activation_negativity': 3.515001253617811e-06,
#  'reconstruction': 7.42937481845729e-05,
#  'total': 0.0003198192862328142,
#  'weight_energy': 6.989230314502493e-05}
# pruned_nmi shape: (3, 5)
# {'active_latents': array([ True,  True,  True,  True,  True, False]),
#  'infoc': 0.5939127804222988,
#  'infoe': 0.9929256045486546,
#  'infom': 0.6878467270186589,
#  'nmi': array([[0.08249334, 0.16423454, 0.05796512, 0.02939343, 0.00435213,
#         0.01966085],
#        [0.02149194, 0.01577096, 0.01970029, 0.        , 0.22059476,
#         0.01207813],
#        [0.01184603, 0.00180591, 0.02145754, 0.11478192, 0.00410611,
#         0.02146427]])}
# {'activation_energy': 1.5008067748567555e-05,
#  'activation_negativity': 4.119299319427228e-06,
#  'reconstruction': 0.000558558851480484,
#  'total': 0.0008198661380447447,
#  'weight_energy': 7.003363862168044e-05}
# pruned_nmi shape: (3, 5)
# {'active_latents': array([ True,  True,  True,  True,  True, False]),
#  'infoc': 0.5847820927796246,
#  'infoe': 0.9926542425283915,
#  'infom': 0.6776717149699504,
#  'nmi': array([[0.08084768, 0.15816613, 0.05724712, 0.02926206, 0.00489865,
#         0.02827192],
#        [0.0234217 , 0.0172385 , 0.02043955, 0.        , 0.21359228,
#         0.01497611],
#        [0.01154129, 0.00175223, 0.0209897 , 0.11462132, 0.00449097,
#         0.02151232]])}
# {'activation_energy': 1.540016455692239e-05,
#  'activation_negativity': 3.9933083826326765e-06,
#  'reconstruction': 4.3283591367071494e-05,
#  'total': 0.00030736761982552707,
#  'weight_energy': 7.014928996795788e-05}
# pruned_nmi shape: (3, 5)
# {'active_latents': array([ True,  True,  True,  True,  True, False]),
#  'infoc': 0.5798903121696658,
#  'infoe': 0.9917686588973789,
#  'infom': 0.6621091668657031,
#  'nmi': array([[7.59507583e-02, 1.48586429e-01, 5.13128198e-02, 2.44436501e-02,
#         5.29081355e-03, 5.52255356e-02],
#        [2.38610430e-02, 1.81079091e-02, 2.05638045e-02, 5.15594500e-05,
#         2.08082296e-01, 1.15222239e-02],
#        [1.29266984e-02, 2.61344319e-03, 2.45134823e-02, 1.26361026e-01,
#         5.10308660e-03, 2.58048819e-02]])}
# {'activation_energy': 1.5270652511389926e-05,
#  'activation_negativity': 3.888734681822825e-06,
#  'reconstruction': 1.5117445400392171e-05,
#  'total': 0.00027696360484696925,
#  'weight_energy': 7.025226659607142e-05}
# pruned_nmi shape: (3, 5)
# {'active_latents': array([ True,  True,  True,  True,  True, False]),
#  'infoc': 0.5791231047074834,
#  'infoe': 0.9923157010064149,
#  'infom': 0.7025089758418103,
#  'nmi': array([[0.0910455 , 0.16640786, 0.06394967, 0.03054255, 0.00781647,
#         0.03442683],
#        [0.01904729, 0.01631461, 0.01518036, 0.        , 0.19133853,
#         0.01761332],
#        [0.01042742, 0.002618  , 0.02210198, 0.11005123, 0.00426638,
#         0.02335394]])}
# {'activation_energy': 1.433190846000798e-05,
#  'activation_negativity': 3.6780081700271694e-06,
#  'reconstruction': 2.6748102754936554e-05,
#  'total': 0.00027718418277800083,
#  'weight_energy': 7.033689325908199e-05}
# pruned_nmi shape: (3, 5)
# {'active_latents': array([ True,  True,  True,  True,  True, False]),
#  'infoc': 0.5743765682685664,
#  'infoe': 0.9927049565095604,
#  'infom': 0.6898416364492254,
#  'nmi': array([[0.08449643, 0.16041401, 0.06419738, 0.03178282, 0.00581856,
#         0.03138027],
#        [0.02220086, 0.01644343, 0.01762148, 0.        , 0.19361607,
#         0.01749936],
#        [0.01089396, 0.00232007, 0.02003951, 0.1090983 , 0.00487987,
#         0.02628433]])}
# {'activation_energy': 1.5911884474917315e-05,
#  'activation_negativity': 4.175828507868573e-06,
#  'reconstruction': 7.354731496889144e-05,
#  'total': 0.0003448660718277097,
#  'weight_energy': 7.044163794489577e-05}
# pruned_nmi shape: (3, 5)
# {'active_latents': array([ True,  True,  True,  True,  True, False]),
#  'infoc': 0.5793407883300324,
#  'infoe': 0.9915993932231292,
#  'infom': 0.6977687897645363,
#  'nmi': array([[0.09270323, 0.16432957, 0.0657581 , 0.03514158, 0.00714324,
#         0.02694009],
#        [0.02072764, 0.01531519, 0.01779028, 0.        , 0.20483796,
#         0.02133322],
#        [0.00909054, 0.00232768, 0.01933174, 0.10081168, 0.00313996,
#         0.02652491]])}
# {'activation_energy': 1.324304048466729e-05,
#  'activation_negativity': 3.292114115538425e-06,
#  'reconstruction': 2.4835033400449902e-05,
#  'total': 0.00026071988395415246,
#  'weight_energy': 7.053330773487687e-05}
# pruned_nmi shape: (3, 5)
# {'active_latents': array([ True,  True,  True,  True,  True, False]),
#  'infoc': 0.5772123825366149,
#  'infoe': 0.9929965220380744,
#  'infom': 0.6903965251280116,
#  'nmi': array([[0.08473186, 0.16080644, 0.06099132, 0.02900274, 0.00587523,
#         0.03104522],
#        [0.02051629, 0.01610514, 0.01640188, 0.        , 0.19600337,
#         0.02951333],
#        [0.01284826, 0.00328635, 0.02270964, 0.11632044, 0.0047871 ,
#         0.024098  ]])}
# {'activation_energy': 1.5484423784073442e-05,
#  'activation_negativity': 3.861444383801427e-06,
#  'reconstruction': 0.001122108194977045,
#  'total': 0.0013862045016139746,
#  'weight_energy': 7.063752855174243e-05}
# pruned_nmi shape: (3, 5)
# {'active_latents': array([ True,  True,  True,  True,  True, False]),
#  'infoc': 0.5718837053700992,
#  'infoe': 0.991200579396004,
#  'infom': 0.6843387410483052,
#  'nmi': array([[0.08440541, 0.15554941, 0.05843863, 0.02745103, 0.0064671 ,
#         0.03417956],
#        [0.0212347 , 0.01728608, 0.015775  , 0.        , 0.18988003,
#         0.02913376],
#        [0.01254657, 0.00346557, 0.0244897 , 0.1189233 , 0.00420044,
#         0.03259388]])}
# {'activation_energy': 1.4280977666203398e-05,
#  'activation_negativity': 3.6120868571742903e-06,
#  'reconstruction': 1.5475483451155014e-05,
#  'total': 0.0002651131071615964,
#  'weight_energy': 7.07069702912122e-05}
# pruned_nmi shape: (3, 5)
# {'active_latents': array([ True,  True,  True,  True,  True, False]),
#  'infoc': 0.5716408454427,
#  'infoe': 0.9922255829767169,
#  'infom': 0.7066281218855196,
#  'nmi': array([[0.09251661, 0.16428539, 0.06664449, 0.03011457, 0.00794105,
#         0.0428091 ],
#        [0.01883078, 0.01505286, 0.01395964, 0.        , 0.18035037,
#         0.02259461],
#        [0.01145073, 0.00372239, 0.02220759, 0.111455  , 0.00444147,
#         0.02094394]])}
# {'activation_energy': 1.3298091289470904e-05,
#  'activation_negativity': 3.3353458093188237e-06,
#  'reconstruction': 0.00030333612812682986,
#  'total': 0.0005404527764767408,
#  'weight_energy': 7.078226190060377e-05}
# pruned_nmi shape: (3, 5)
# {'active_latents': array([ True,  True,  True,  True,  True, False]),
#  'infoc': 0.5669738409029786,
#  'infoe': 0.9930998999448605,
#  'infom': 0.7008757085187836,
#  'nmi': array([[0.08989561, 0.15920011, 0.06718732, 0.03114066, 0.00696145,
#         0.03207657],
#        [0.0193647 , 0.01631638, 0.01481437, 0.        , 0.18397657,
#         0.01986041],
#        [0.01162931, 0.00474796, 0.02060849, 0.11030269, 0.00446256,
#         0.02807435]])}
# {'activation_energy': 1.3552471500588581e-05,
#  'activation_negativity': 3.465468353169854e-06,
#  'reconstruction': 2.2092763174441643e-05,
#  'total': 0.00026314001297578216,
#  'weight_energy': 7.086781261023134e-05}
# pruned_nmi shape: (3, 5)
# {'active_latents': array([ True,  True,  True,  True,  True, False]),
#  'infoc': 0.5636890331545141,
#  'infoe': 0.9927373900919875,
#  'infom': 0.6900366019022662,
#  'nmi': array([[0.089886  , 0.15486051, 0.06757892, 0.03526372, 0.00660159,
#         0.04772534],
#        [0.02191863, 0.01767611, 0.01686955, 0.        , 0.19486958,
#         0.02054837],
#        [0.01007977, 0.00385855, 0.01837427, 0.10294003, 0.00380129,
#         0.02247341]])}
# {'activation_energy': 1.59387582243653e-05,
#  'activation_negativity': 4.33908599006827e-06,
#  'reconstruction': 7.003032806096599e-05,
#  'total': 0.0003437325358390808,
#  'weight_energy': 7.092378655215725e-05}
# pruned_nmi shape: (3, 5)
# {'active_latents': array([ True,  True,  True,  True,  True, False]),
#  'infoc': 0.5596624124741504,
#  'infoe': 0.9916614291470315,
#  'infom': 0.710434674828568,
#  'nmi': array([[0.1066525 , 0.16696927, 0.08046709, 0.04175481, 0.00893822,
#         0.04710526],
#        [0.01749991, 0.01687768, 0.01577534, 0.        , 0.18501939,
#         0.01532898],
#        [0.0072102 , 0.00408075, 0.01613599, 0.0881375 , 0.0029066 ,
#         0.03815958]])}
# {'activation_energy': 1.4805375030846335e-05,
#  'activation_negativity': 3.848841060971608e-06,
#  'reconstruction': 0.00030388921732082963,
#  'total': 0.0005614000838249922,
#  'weight_energy': 7.096868648659438e-05}
# pruned_nmi shape: (3, 5)
# {'active_latents': array([ True,  True,  True,  True,  True, False]),
#  'infoc': 0.5363980959832748,
#  'infoe': 0.9918050364723768,
#  'infom': 0.6849535935926593,
#  'nmi': array([[0.08901111, 0.14024352, 0.07257086, 0.0344764 , 0.00697434,
#         0.01688035],
#        [0.02191695, 0.02134233, 0.01441585, 0.        , 0.17616625,
#         0.02432549],
#        [0.01036337, 0.00609501, 0.01777276, 0.10210832, 0.00441159,
#         0.04831995]])}
# {'activation_energy': 1.3071145986032207e-05,
#  'activation_negativity': 3.341076535434695e-06,
#  'reconstruction': 8.278254244942218e-05,
#  'total': 0.0003179183404427022,
#  'weight_energy': 7.101357914507389e-05}
# pruned_nmi shape: (3, 5)
# {'active_latents': array([ True,  True,  True,  True,  True, False]),
#  'infoc': 0.5420437080867282,
#  'infoe': 0.9928522551056881,
#  'infom': 0.691361357637814,
#  'nmi': array([[0.09311859, 0.14703711, 0.07033927, 0.03268149, 0.00703433,
#         0.04535155],
#        [0.02002858, 0.01978997, 0.01377972, 0.        , 0.17941505,
#         0.01502065],
#        [0.01199192, 0.00745903, 0.01982951, 0.10807674, 0.00463363,
#         0.02221479]])}
# {'activation_energy': 1.2796784176316578e-05,
#  'activation_negativity': 3.2941259178187465e-06,
#  'reconstruction': 0.0001734834659146145,
#  'total': 0.0004054614109918475,
#  'weight_energy': 7.106880366336554e-05}
# pruned_nmi shape: (3, 5)
# {'active_latents': array([ True,  True,  True,  True,  True, False]),
#  'infoc': 0.525988339198827,
#  'infoe': 0.9928777006698047,
#  'infom': 0.6765533729252674,
#  'nmi': array([[0.09156218, 0.13739887, 0.06903482, 0.03206835, 0.00733124,
#         0.0476558 ],
#        [0.02082632, 0.02197328, 0.01436386, 0.        , 0.1780571 ,
#         0.01955288],
#        [0.01224875, 0.01053728, 0.02008944, 0.1092477 , 0.00435656,
#         0.02266328]])}
# {'activation_energy': 1.3721528375754133e-05,
#  'activation_negativity': 3.6670467125077266e-06,
#  'reconstruction': 7.480265048798174e-05,
#  'total': 0.0003198489430360496,
#  'weight_energy': 7.116052438504994e-05}
# pruned_nmi shape: (3, 4)
# {'active_latents': array([ True, False,  True,  True,  True, False]),
#  'infoc': 0.5751651877059581,
#  'infoe': 0.9916205559433479,
#  'infom': 0.6509043908287264,
#  'nmi': array([[0.0837903 , 0.10650593, 0.06052692, 0.02682937, 0.00641908,
#         0.02280846],
#        [0.02289924, 0.03230237, 0.01586594, 0.        , 0.18182082,
#         0.01392327],
#        [0.01359342, 0.01935048, 0.02287538, 0.12122484, 0.00437697,
#         0.03135306]])}
# {'activation_energy': 1.3049801964371e-05,
#  'activation_negativity': 3.3946498660952784e-06,
#  'reconstruction': 9.5197119662771e-06,
#  'total': 0.0002452163607813418,
#  'weight_energy': 7.125210686353967e-05}
# pruned_nmi shape: (3, 4)
# {'active_latents': array([ True, False,  True,  True,  True, False]),
#  'infoc': 0.5664060254546285,
#  'infoe': 0.9922217816255546,
#  'infom': 0.6605075599907768,
#  'nmi': array([[0.08784476, 0.05940433, 0.06829122, 0.03175045, 0.00706427,
#         0.03883442],
#        [0.02248917, 0.01404475, 0.01472689, 0.        , 0.17273748,
#         0.02086275],
#        [0.01145203, 0.02024043, 0.02016387, 0.11002242, 0.00484882,
#         0.0315251 ]])}
# {'activation_energy': 1.3183658666093834e-05,
#  'activation_negativity': 3.839419150608592e-06,
#  'reconstruction': 2.509446676413063e-05,
#  'total': 0.0002666468499228358,
#  'weight_energy': 7.132160681067035e-05}
# pruned_nmi shape: (3, 4)
# {'active_latents': array([ True, False,  True,  True,  True, False]),
#  'infoc': 0.5690167972339425,
#  'infoe': 0.9922180882650804,
#  'infom': 0.6374795186168355,
#  'nmi': array([[0.08199152, 0.04347773, 0.06180156, 0.03172573, 0.00689653,
#         0.03321902],
#        [0.02582787, 0.01160232, 0.01960088, 0.        , 0.19641204,
#         0.03608963],
#        [0.01100515, 0.01832705, 0.01903573, 0.11034176, 0.00316884,
#         0.0199894 ]])}
# {'activation_energy': 1.2854224223701749e-05,
#  'activation_negativity': 3.250478812333313e-06,
#  'reconstruction': 0.00040433721733279526,
#  'total': 0.0006367358728311956,
#  'weight_energy': 7.135156920412555e-05}
# pruned_nmi shape: (3, 4)
# {'active_latents': array([ True, False,  True,  True,  True, False]),
#  'infoc': 0.5710137931825887,
#  'infoe': 0.9924304923709429,
#  'infom': 0.6739804102667257,
#  'nmi': array([[0.09627117, 0.06528527, 0.0747828 , 0.03536303, 0.00664733,
#         0.0325752 ],
#        [0.02087646, 0.01002604, 0.01395523, 0.        , 0.17480225,
# ...
#  'weight_energy': 6.782601121813059e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.7090828948582445,
#  'infoe': 0.9927160855522689,
#  'infom': 0.7092207082874203,
#  'nmi': array([[0.05691257, 0.02354324, 0.07998744, 0.03269123, 0.00812094,
#         0.01325178],
#        [0.01420421, 0.02775365, 0.01191284, 0.        , 0.1600661 ,
#         0.02981731],
#        [0.01397611, 0.04573972, 0.01857413, 0.10562354, 0.00378663,
#         0.05046085]])}
# {'activation_energy': 1.0479551747266669e-05,
#  'activation_negativity': 2.864728685381124e-06,
#  'reconstruction': 0.00011230531526962295,
#  'total': 0.00031353483791463077,
#  'weight_energy': 6.778671377105638e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.7071743203422125,
#  'infoe': 0.9913699755790253,
#  'infom': 0.7029216051163572,
#  'nmi': array([[0.04716669, 0.04486983, 0.08786274, 0.03466992, 0.01251729,
#         0.04071697],
#        [0.07168922, 0.03965825, 0.00888056, 0.        , 0.13991427,
#         0.03343473],
#        [0.01302691, 0.02754349, 0.0183324 , 0.10035106, 0.00318501,
#         0.03318654]])}
# {'activation_energy': 9.873256203718483e-06,
#  'activation_negativity': 2.6749944481707644e-06,
#  'reconstruction': 0.00013332456001080573,
#  'total': 0.0003265603445470333,
#  'weight_energy': 6.775328074581921e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.7060281756874444,
#  'infoe': 0.9921460994914924,
#  'infom': 0.7071780601685784,
#  'nmi': array([[0.02055104, 0.05993943, 0.07516436, 0.03014844, 0.00918022,
#         0.0820365 ],
#        [0.01361181, 0.02174869, 0.01133019, 0.        , 0.15712396,
#         0.03276647],
#        [0.10807329, 0.06175188, 0.02142878, 0.11273055, 0.00284598,
#         0.02053186]])}
# {'activation_energy': 1.0818779628607444e-05,
#  'activation_negativity': 2.8693038984783925e-06,
#  'reconstruction': 0.00045832767500542104,
#  'total': 0.0006629193085245788,
#  'weight_energy': 6.771086918888614e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.7130192577160842,
#  'infoe': 0.9907066844421073,
#  'infom': 0.7066454887310524,
#  'nmi': array([[0.01238124, 0.06313294, 0.09236125, 0.03646121, 0.01171775,
#         0.06645456],
#        [0.03631056, 0.01525392, 0.00852058, 0.        , 0.14103157,
#         0.01782015],
#        [0.010606  , 0.00929405, 0.01604462, 0.09608854, 0.00422143,
#         0.03122905]])}
# {'activation_energy': 9.600815246813e-06,
#  'activation_negativity': 2.60921660810709e-06,
#  'reconstruction': 2.8196644052513875e-05,
#  'total': 0.00021794027998112142,
#  'weight_energy': 6.764331192243844e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.711312354350358,
#  'infoe': 0.9917298462619607,
#  'infom': 0.7126547034890177,
#  'nmi': array([[0.01268105, 0.01405579, 0.07620652, 0.02880107, 0.00862761,
#         0.01071735],
#        [0.01253616, 0.0270937 , 0.01051386, 0.        , 0.15169772,
#         0.04419278],
#        [0.04938533, 0.04759824, 0.02160422, 0.11487407, 0.00415809,
#         0.03828398]])}
# {'activation_energy': 9.985704309656285e-06,
#  'activation_negativity': 2.7489754756970797e-06,
#  'reconstruction': 3.6890160117764026e-05,
#  'total': 0.0002318211190868169,
#  'weight_energy': 6.758415111107752e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.6910178857377214,
#  'infoe': 0.991216494452957,
#  'infom': 0.6923942747445649,
#  'nmi': array([[0.03681742, 0.05213901, 0.07181898, 0.03021879, 0.01248815,
#         0.04216139],
#        [0.02918677, 0.02220052, 0.0113153 , 0.        , 0.15957465,
#         0.02478   ],
#        [0.02412638, 0.01604281, 0.02142956, 0.10869999, 0.00224549,
#         0.02461615]])}
# {'activation_energy': 9.47260923567228e-06,
#  'activation_negativity': 2.5934684799722163e-06,
#  'reconstruction': 5.527969278773526e-06,
#  'total': 0.00019370106747373939,
#  'weight_energy': 6.75123228575103e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.7062666123058048,
#  'infoe': 0.9926788522693263,
#  'infom': 0.7074540813399923,
#  'nmi': array([[0.04024122, 0.03534083, 0.07608527, 0.03109286, 0.00990023,
#         0.02001041],
#        [0.03760806, 0.02729164, 0.01107672, 0.        , 0.15779875,
#         0.03135931],
#        [0.02793351, 0.0280288 , 0.02047766, 0.11086494, 0.00251054,
#         0.04092384]])}
# {'activation_energy': 9.650759238866158e-06,
#  'activation_negativity': 2.5751671728357906e-06,
#  'reconstruction': 0.00016306564793922007,
#  'total': 0.00035277887945994735,
#  'weight_energy': 6.745395512552932e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.7073634746439104,
#  'infoe': 0.992029848636181,
#  'infom': 0.7049349826735273,
#  'nmi': array([[0.05451177, 0.04969972, 0.08572202, 0.03300709, 0.0129122 ,
#         0.03256889],
#        [0.01398515, 0.0301555 , 0.00846051, 0.        , 0.13884411,
#         0.0515832 ],
#        [0.01826462, 0.02275956, 0.01919423, 0.1046402 , 0.00362266,
#         0.02902796]])}
# {'activation_energy': 1.046221859724028e-05,
#  'activation_negativity': 2.8366280275804456e-06,
#  'reconstruction': 5.7359979109605774e-05,
#  'total': 0.0002577647683210671,
#  'weight_energy': 6.741632387274876e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.7129111704282751,
#  'infoe': 0.9913623891885868,
#  'infom': 0.7132295940101838,
#  'nmi': array([[0.03053081, 0.07550745, 0.07855942, 0.02750165, 0.01114941,
#         0.03903402],
#        [0.07912614, 0.0164701 , 0.00802299, 0.        , 0.13936915,
#         0.04356105],
#        [0.02109746, 0.01643387, 0.02236655, 0.11725206, 0.0051347 ,
#         0.01862458]])}
# {'activation_energy': 1.0187350198975764e-05,
#  'activation_negativity': 2.758652271950268e-06,
#  'reconstruction': 0.0002460760879330337,
#  'total': 0.00044292520033195615,
#  'weight_energy': 6.738908996339887e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.6993770665393727,
#  'infoe': 0.9913199100890422,
#  'infom': 0.6936614463136331,
#  'nmi': array([[0.04296856, 0.05392283, 0.08537672, 0.03421442, 0.01535735,
#         0.02372361],
#        [0.01935808, 0.01920027, 0.0085271 , 0.        , 0.13887979,
#         0.04496139],
#        [0.03328335, 0.03707067, 0.01928165, 0.09931649, 0.00194036,
#         0.02852625]])}
# {'activation_energy': 9.570603651809506e-06,
#  'activation_negativity': 2.623826048875344e-06,
#  'reconstruction': 6.896381819387898e-06,
#  'total': 0.000196179942577146,
#  'weight_energy': 6.733926420565695e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.7064933370185715,
#  'infoe': 0.9922969783747075,
#  'infom': 0.7080035453426258,
#  'nmi': array([[0.01399974, 0.03682946, 0.07410158, 0.02893783, 0.00976018,
#         0.01542171],
#        [0.01980568, 0.02040257, 0.01027918, 0.        , 0.15337571,
#         0.05309116],
#        [0.05633666, 0.03341615, 0.02256472, 0.11672387, 0.00325481,
#         0.02464499]])}
# {'activation_energy': 9.826193490880542e-06,
#  'activation_negativity': 2.6657130547391716e-06,
#  'reconstruction': 1.848882129706908e-05,
#  'total': 0.00021071202354505658,
#  'weight_energy': 6.730412860633805e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.6993711574975235,
#  'infoe': 0.9917242072130549,
#  'infom': 0.7007423743522289,
#  'nmi': array([[0.06430711, 0.03212748, 0.07353747, 0.02923169, 0.01090528,
#         0.02895767],
#        [0.02101782, 0.03657608, 0.01038373, 0.        , 0.15414316,
#         0.04831409],
#        [0.01286892, 0.02186428, 0.02313944, 0.11434563, 0.00282629,
#         0.03343066]])}
# {'activation_energy': 9.61532259680098e-06,
#  'activation_negativity': 2.5747058316483162e-06,
#  'reconstruction': 2.5835852284217253e-05,
#  'total': 0.00021498689602594823,
#  'weight_energy': 6.725075945723802e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.7083061877148871,
#  'infoe': 0.9920665280998794,
#  'infom': 0.7097277301799074,
#  'nmi': array([[0.02386846, 0.05862887, 0.07811802, 0.03049063, 0.00972892,
#         0.02442559],
#        [0.01922016, 0.01472674, 0.01021496, 0.        , 0.15134111,
#         0.03647059],
#        [0.05067619, 0.02186531, 0.02110937, 0.11265458, 0.00366791,
#         0.01750177]])}
# {'activation_energy': 9.329774911748245e-06,
#  'activation_negativity': 2.5539602575008757e-06,
#  'reconstruction': 0.00021463906159624457,
#  'total': 0.0004006776725873351,
#  'weight_energy': 6.720125384163111e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.7143159766463387,
#  'infoe': 0.9925012914364982,
#  'infom': 0.7158427887304333,
#  'nmi': array([[0.04395652, 0.02023934, 0.07777747, 0.03011547, 0.00837449,
#         0.02021864],
#        [0.01343486, 0.02420698, 0.01071378, 0.        , 0.155989  ,
#         0.03379601],
#        [0.0350515 , 0.04125173, 0.02011288, 0.11179317, 0.00377393,
#         0.03503936]])}
# {'activation_energy': 1.190943021356361e-05,
#  'activation_negativity': 3.3278647606493905e-06,
#  'reconstruction': 0.0006096747238188982,
#  'total': 0.0008292414713650942,
#  'weight_energy': 6.719378143316135e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.7226514235297661,
#  'infoe': 0.9898923581315572,
#  'infom': 0.6972228787111057,
#  'nmi': array([[0.03003056, 0.0177702 , 0.1059873 , 0.04258575, 0.0135628 ,
#         0.04646417],
#        [0.03303324, 0.04897691, 0.0082231 , 0.        , 0.13536147,
#         0.0111399 ],
#        [0.03130734, 0.04980843, 0.01200147, 0.08390658, 0.00293598,
#         0.04945404]])}
# {'activation_energy': 9.126718396146316e-06,
#  'activation_negativity': 2.4486685106239747e-06,
#  'reconstruction': 1.643819450691808e-05,
#  'total': 0.0001993469923036173,
#  'weight_energy': 6.715492781950161e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.7145497141060637,
#  'infoe': 0.9927201483179334,
#  'infom': 0.7160453202024626,
#  'nmi': array([[0.0386201 , 0.03013464, 0.07854878, 0.03044745, 0.00871475,
#         0.03063509],
#        [0.02328576, 0.0210723 , 0.01028031, 0.        , 0.15403085,
#         0.02420675],
#        [0.02955158, 0.02364881, 0.02019541, 0.11128738, 0.00351516,
#         0.03049301]])}
# {'activation_energy': 9.254605174646713e-06,
#  'activation_negativity': 2.499665924915462e-06,
#  'reconstruction': 3.1173294701147825e-05,
#  'total': 0.00021587664377875626,
#  'weight_energy': 6.716063944622874e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.709399883228571,
#  'infoe': 0.9927832596237373,
#  'infom': 0.7104613356253111,
#  'nmi': array([[0.03637714, 0.01426991, 0.07901479, 0.03166875, 0.00953913,
#         0.01384441],
#        [0.03320028, 0.03913048, 0.01029988, 0.        , 0.1541296 ,
#         0.11119818],
#        [0.02123381, 0.04216394, 0.02034658, 0.10951032, 0.00301127,
#         0.01654342]])}
# {'activation_energy': 1.050373430189211e-05,
#  'activation_negativity': 3.0588444133172743e-06,
#  'reconstruction': 1.1383561286493205e-05,
#  'total': 0.00021418757387436926,
#  'weight_energy': 6.717822543578222e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.6994681302629484,
#  'infoe': 0.9914558246865234,
#  'infom': 0.6999779636044918,
#  'nmi': array([[0.02784343, 0.04123889, 0.07264177, 0.0313964 , 0.00960933,
#         0.06587961],
#        [0.06235299, 0.04309374, 0.01301674, 0.        , 0.16594874,
#         0.026768  ],
#        [0.02456869, 0.0182741 , 0.01980692, 0.11065419, 0.00245929,
#         0.04455246]])}
# {'activation_energy': 9.562400009599514e-06,
#  'activation_negativity': 2.592917326182942e-06,
#  'reconstruction': 8.827382771414705e-06,
#  'total': 0.0001975140767171979,
#  'weight_energy': 6.71335292281583e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.7067025284965949,
#  'infoe': 0.991960487064055,
#  'infom': 0.7080632351775569,
#  'nmi': array([[0.01759713, 0.02005384, 0.07396264, 0.03005608, 0.00901115,
#         0.01442464],
#        [0.02375129, 0.02709003, 0.01137793, 0.        , 0.15912069,
#         0.04762668],
#        [0.05258105, 0.04086644, 0.02124801, 0.1139387 , 0.00279125,
#         0.02434027]])}
# {'activation_energy': 1.0208985258941539e-05,
#  'activation_negativity': 2.8512347398645943e-06,
#  'reconstruction': 1.9824379705823958e-05,
#  'total': 0.00021755232592113316,
#  'weight_energy': 6.712575850542635e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.7019420358959451,
#  'infoe': 0.9917222326970544,
#  'infom': 0.7027584900235228,
#  'nmi': array([[0.01300095, 0.06402536, 0.07331505, 0.03091942, 0.00929978,
#         0.04583653],
#        [0.09094041, 0.03834801, 0.01240959, 0.        , 0.16142541,
#         0.04368016],
#        [0.02509467, 0.01184189, 0.0205284 , 0.11179746, 0.00244805,
#         0.01709528]])}
# {'activation_energy': 1.0036599633167498e-05,
#  'activation_negativity': 2.742430979196797e-06,
#  'reconstruction': 6.4352989284088835e-06,
#  'total': 0.00020131768542341888,
#  'weight_energy': 6.709209264954552e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.7082137537850152,
#  'infoe': 0.9915954429641767,
#  'infom': 0.7095741895291009,
#  'nmi': array([[0.02207293, 0.01936652, 0.07600546, 0.0301418 , 0.00927222,
#         0.01604068],
#        [0.01428961, 0.03462231, 0.01076903, 0.        , 0.15558572,
#         0.03712915],
#        [0.05319227, 0.04120901, 0.02136301, 0.11287026, 0.00297035,
#         0.01791211]])}
# {'activation_energy': 8.927301678340882e-06,
#  'activation_negativity': 2.4222954380093142e-06,
#  'reconstruction': 0.0002886969596147537,
#  'total': 0.00046926006325520575,
#  'weight_energy': 6.706710701109841e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.7088094343318856,
#  'infoe': 0.993005417764062,
#  'infom': 0.7102374771987271,
#  'nmi': array([[0.05489742, 0.01967143, 0.07692726, 0.03045765, 0.00946001,
#         0.02518267],
#        [0.01816504, 0.04641504, 0.0107967 , 0.        , 0.15359987,
#         0.05541793],
#        [0.02114711, 0.02133948, 0.0208932 , 0.11324954, 0.00314225,
#         0.05012971]])}
# {'activation_energy': 9.484683687333018e-06,
#  'activation_negativity': 2.5333374651381746e-06,
#  'reconstruction': 2.1206888050073758e-05,
#  'total': 0.0002084527222905308,
#  'weight_energy': 6.706562271574512e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.7098737339680963,
#  'infoe': 0.9923588997318008,
#  'infom': 0.7107071714657345,
#  'nmi': array([[0.09231957, 0.06868442, 0.079673  , 0.03202509, 0.00966807,
#         0.03466708],
#        [0.01314284, 0.01331798, 0.01034296, 0.        , 0.15390295,
#         0.02768339],
#        [0.0229596 , 0.02104578, 0.01992831, 0.10865733, 0.00292067,
#         0.03383171]])}
# {'activation_energy': 9.334623428003397e-06,
#  'activation_negativity': 2.4322687295352807e-06,
#  'reconstruction': 0.00019468623213469982,
#  'total': 0.0003794098156504333,
#  'weight_energy': 6.705467967549339e-05}
# pruned_nmi shape: (3, 3)
# {'active_latents': array([False, False,  True,  True,  True, False]),
#  'infoc': 0.7106527294801845,
#  'infoe': 0.9928162735742984,
#  'infom': 0.7118371486709253,
#  'nmi': array([[0.02422138, 0.02340199, 0.0792384 , 0.03158074, 0.00930183,
#         0.02848035],
#        [0.02810463, 0.03095304, 0.01019949, 0.        , 0.15340176,
#         0.02656197],
#        [0.02590942, 0.02924723, 0.02032708, 0.11006334, 0.00318255,
#         0.01733156]])}

# %%
metrics = infomec.compute_infomec(data['s'], aux['z'], 'continuous', 'continuous')
pprint.pprint(metrics)
sns.heatmap(metrics['nmi'], vmin=0, vmax=1, annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 metrics = infomec.compute_infomec(data['s'], aux['z'], 'continuous', 'continuous')
#       2 pprint.pprint(metrics)
#       3 sns.heatmap(metrics['nmi'], vmin=0, vmax=1, annot=True)
#
# NameError: name 'infomec' is not defined

# %%
fig, axes = plt.subplots(LATENT_SIZE, LATENT_SIZE, figsize=(20, 20))
for i in range(LATENT_SIZE):
    for j in range(LATENT_SIZE):
        axes[i, j].scatter(aux['z'][:, i], aux['z'][:, j])

# %%
# Out:
# <Axes: >

# %%
metrics = infomec.compute_infomec(data['s'], aux['z'], False)
sns.heatmap(metrics['nmi'], vmin=0, vmax=1, annot=True)
# Out:
# pruned_nmi shape: (2, 4)
# <Axes: >
